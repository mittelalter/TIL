# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
iris_data = load_iris()

# %%
X = pd.DataFrame(iris_data.data, columns=iris_data.feature_names)

# %%
y = pd.DataFrame(iris_data.target, columns=['Class'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
model = DecisionTreeClassifier(max_depth=4)

# %%
model.fit(X_train, y_train) # 모델 학습
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
model.predict(X_test) # 모델로 test set 예측 ( 모델을 만드는 이유는 현실이 너무도 복잡하기 때문에
                                                #모델을 만들어 그 모델로 현실을 예측 하기 위함 )
# Out:
# array([1, 2, 2, 0, 2, 2, 0, 2, 0, 1, 1, 1, 2, 2, 0, 0, 2, 2, 0, 0, 1, 2,
#        0, 1, 1, 2, 1, 1, 1, 2])

# %%
model.score(X_test, y_test) # 모델 성능 평가 # 90 프로 확률로 제대로 분류한다는 의미이다.
# Out:
# 0.9

# %%
importances = model.feature_importances_
importances
# Out:
# array([0.02378049, 0.        , 0.02264808, 0.95357143])

# %%
indices_sorted = np.argsort(importances)

plt.figure()
plt.title("Feature Importrance")
plt.bar(range(len(importances)), importances[indices_sorted])
plt.xticks(range(len(importances)), X.columns[indices_sorted], rotation=90)
plt.show()

# %%
# 꽃잎 길이가 가장 중요하게 사용된다.

# %%
from sklearn.datasets import load_iris
from sklearn import tree
import matplotlib.pyplot as plt
X, y = load_iris(return_X_y=True)
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)
plt.figure(figsize=[15, 15])
tree.plot_tree(clf)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
